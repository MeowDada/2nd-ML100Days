# %% [markdown]
# ## [作業重點]
# 使用 Sklearn 中的線性迴歸模型，來訓練各種資料集，務必了解送進去模型訓練的**資料型態**為何，也請了解模型中各項參數的意義

# %% [markdown]
# ## 作業
# 試著使用 sklearn datasets 的其他資料集 (wine, boston, ...)，來訓練自己的線性迴歸模型。

# %% [markdown]
# ### HINT: 注意 label 的型態，確定資料集的目標是分類還是回歸，在使用正確的模型訓練！

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, mean_absolute_error

# %%
wine = datasets.load_wine()
boston = datasets.load_boston()
breast_cancer = datasets.load_breast_cancer()

# %% [markdown]
# # Wine dataset

# %%
dataset = wine

# %%
dataset.data[:5,:]
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, 1.560e+01, 1.270e+02, 2.800e+00,
#         3.060e+00, 2.800e-01, 2.290e+00, 5.640e+00, 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, 1.120e+01, 1.000e+02, 2.650e+00,
#         2.760e+00, 2.600e-01, 1.280e+00, 4.380e+00, 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.316e+01, 2.360e+00, 2.670e+00, 1.860e+01, 1.010e+02, 2.800e+00,
#         3.240e+00, 3.000e-01, 2.810e+00, 5.680e+00, 1.030e+00, 3.170e+00,
#         1.185e+03],
#        [1.437e+01, 1.950e+00, 2.500e+00, 1.680e+01, 1.130e+02, 3.850e+00,
#         3.490e+00, 2.400e-01, 2.180e+00, 7.800e+00, 8.600e-01, 3.450e+00,
#         1.480e+03],
#        [1.324e+01, 2.590e+00, 2.870e+00, 2.100e+01, 1.180e+02, 2.800e+00,
#         2.690e+00, 3.900e-01, 1.820e+00, 4.320e+00, 1.040e+00, 2.930e+00,
#         7.350e+02]])

# %%
dataset.target[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
x_train, x_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.2, random_state=4)
log_reg = linear_model.LogisticRegression().fit(x_train, y_train)
y_pred = log_reg.predict(x_test)


acc = accuracy_score(y_test, y_pred)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.9722222222222222
# C:\Users\Scherzando\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Scherzando\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %% [markdown]
# # Boston dataset

# %%
dataset = boston

# %%
dataset.data[:5,:]
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, 0.0000e+00, 5.3800e-01,
#         6.5750e+00, 6.5200e+01, 4.0900e+00, 1.0000e+00, 2.9600e+02,
#         1.5300e+01, 3.9690e+02, 4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01,
#         6.4210e+00, 7.8900e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02,
#         1.7800e+01, 3.9690e+02, 9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01,
#         7.1850e+00, 6.1100e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02,
#         1.7800e+01, 3.9283e+02, 4.0300e+00],
#        [3.2370e-02, 0.0000e+00, 2.1800e+00, 0.0000e+00, 4.5800e-01,
#         6.9980e+00, 4.5800e+01, 6.0622e+00, 3.0000e+00, 2.2200e+02,
#         1.8700e+01, 3.9463e+02, 2.9400e+00],
#        [6.9050e-02, 0.0000e+00, 2.1800e+00, 0.0000e+00, 4.5800e-01,
#         7.1470e+00, 5.4200e+01, 6.0622e+00, 3.0000e+00, 2.2200e+02,
#         1.8700e+01, 3.9690e+02, 5.3300e+00]])

# %%
dataset.target[:5]
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2])

# %%
features = dataset.feature_names

# %%
for idx, feature in enumerate(features):
    data = dataset.data[:, np.newaxis, idx]
    x_train, x_test, y_train, y_test = train_test_split(data, dataset.target, test_size=0.2, random_state=4)
    lin_reg = linear_model.LinearRegression()
    lin_reg.fit(x_train, y_train)
    y_pred = lin_reg.predict(x_test)
    
    plt.title(feature)
    # 畫出回歸模型與實際資料的分佈
    plt.scatter(x_test, y_test,  color='black')
    plt.plot(x_test, y_pred, color='blue', linewidth=1)
    plt.show()
    
    # 預測值與實際值的差距，使用 MSE
    print("Mean squared error: %.2f"
          % mean_squared_error(y_test, y_pred))

    # 預測值與實際值的差距，使用 MAE
    print("Mean squared error: %.2f"
          % mean_absolute_error(y_test, y_pred))
# Out:
# Mean squared error: 84.85
# Mean squared error: 6.79
# Mean squared error: 76.74
# Mean squared error: 6.11
# Mean squared error: 75.47
# Mean squared error: 6.14
# Mean squared error: 95.21
# Mean squared error: 7.20
# Mean squared error: 76.60
# Mean squared error: 6.24
# Mean squared error: 51.61
# Mean squared error: 4.57
# Mean squared error: 79.39
# Mean squared error: 6.01
# Mean squared error: 88.03
# Mean squared error: 6.61
# Mean squared error: 88.52
# Mean squared error: 6.81
# Mean squared error: 82.95
# Mean squared error: 6.62
# Mean squared error: 71.52
# Mean squared error: 6.01
# Mean squared error: 81.90
# Mean squared error: 6.46
# Mean squared error: 40.13
# Mean squared error: 4.40

# %% [markdown]
# # Breast Cancer

# %%
dataset = breast_cancer

# %%
dataset.data[:5,:]
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, 1.001e+03, 1.184e-01, 2.776e-01,
#         3.001e-01, 1.471e-01, 2.419e-01, 7.871e-02, 1.095e+00, 9.053e-01,
#         8.589e+00, 1.534e+02, 6.399e-03, 4.904e-02, 5.373e-02, 1.587e-02,
#         3.003e-02, 6.193e-03, 2.538e+01, 1.733e+01, 1.846e+02, 2.019e+03,
#         1.622e-01, 6.656e-01, 7.119e-01, 2.654e-01, 4.601e-01, 1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, 1.326e+03, 8.474e-02, 7.864e-02,
#         8.690e-02, 7.017e-02, 1.812e-01, 5.667e-02, 5.435e-01, 7.339e-01,
#         3.398e+00, 7.408e+01, 5.225e-03, 1.308e-02, 1.860e-02, 1.340e-02,
#         1.389e-02, 3.532e-03, 2.499e+01, 2.341e+01, 1.588e+02, 1.956e+03,
#         1.238e-01, 1.866e-01, 2.416e-01, 1.860e-01, 2.750e-01, 8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, 1.203e+03, 1.096e-01, 1.599e-01,
#         1.974e-01, 1.279e-01, 2.069e-01, 5.999e-02, 7.456e-01, 7.869e-01,
#         4.585e+00, 9.403e+01, 6.150e-03, 4.006e-02, 3.832e-02, 2.058e-02,
#         2.250e-02, 4.571e-03, 2.357e+01, 2.553e+01, 1.525e+02, 1.709e+03,
#         1.444e-01, 4.245e-01, 4.504e-01, 2.430e-01, 3.613e-01, 8.758e-02],
#        [1.142e+01, 2.038e+01, 7.758e+01, 3.861e+02, 1.425e-01, 2.839e-01,
#         2.414e-01, 1.052e-01, 2.597e-01, 9.744e-02, 4.956e-01, 1.156e+00,
#         3.445e+00, 2.723e+01, 9.110e-03, 7.458e-02, 5.661e-02, 1.867e-02,
#         5.963e-02, 9.208e-03, 1.491e+01, 2.650e+01, 9.887e+01, 5.677e+02,
#         2.098e-01, 8.663e-01, 6.869e-01, 2.575e-01, 6.638e-01, 1.730e-01],
#        [2.029e+01, 1.434e+01, 1.351e+02, 1.297e+03, 1.003e-01, 1.328e-01,
#         1.980e-01, 1.043e-01, 1.809e-01, 5.883e-02, 7.572e-01, 7.813e-01,
#         5.438e+00, 9.444e+01, 1.149e-02, 2.461e-02, 5.688e-02, 1.885e-02,
#         1.756e-02, 5.115e-03, 2.254e+01, 1.667e+01, 1.522e+02, 1.575e+03,
#         1.374e-01, 2.050e-01, 4.000e-01, 1.625e-01, 2.364e-01, 7.678e-02]])

# %%
dataset.target[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
x_train, x_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.2, random_state=4)
log_reg = linear_model.LogisticRegression().fit(x_train, y_train)
y_pred = log_reg.predict(x_test)


acc = accuracy_score(y_test, y_pred)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.9122807017543859
# C:\Users\Scherzando\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
